# %%
import pandas as pd

# %%
df = pd.read_csv('WDIData.csv')
df.head(5)
# Out:
#                   Country Name Country Code  \
# 0  Africa Eastern and Southern          AFE
# 1  Africa Eastern and Southern          AFE
# 2  Africa Eastern and Southern          AFE
# 3  Africa Eastern and Southern          AFE
# 4  Africa Eastern and Southern          AFE
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS   NaN
# 1  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.RU.ZS   NaN
# 2  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.UR.ZS   NaN
# 3            Access to electricity (% of population)     EG.ELC.ACCS.ZS   NaN
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...       2013       2014       2015  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  16.789043  17.196986  17.597176
# 1   NaN   NaN   NaN   NaN   NaN  ...   6.397917   6.580066   6.786218
# ...

# %% [markdown]
# ## Transpose the dataframe

# %%
df = df.transpose()

# %%
df.head(5)
# Out:
#                                                            0       \
# Country Name                          Africa Eastern and Southern
# Country Code                                                  AFE
# Indicator Name  Access to clean fuels and technologies for coo...
# Indicator Code                                     EG.CFT.ACCS.ZS
# 1960                                                          NaN
#
#                                                            1       \
# Country Name                          Africa Eastern and Southern
# Country Code                                                  AFE
# Indicator Name  Access to clean fuels and technologies for coo...
# Indicator Code                                  EG.CFT.ACCS.RU.ZS
# 1960                                                          NaN
#
#                                                            2       \
# Country Name                          Africa Eastern and Southern
# ...

# %% [markdown]
# # Most of the countries have no data from 1960-1999 so dropping the dates

# %%
df.drop(df.iloc[4:44].index, inplace=True)

# %%
df.isna().sum()
# Out:
# 0          2
# 1          2
# 2          2
# 3          2
# 4          4
#           ..
# 383567    20
# 383568    19
# 383569    17
# 383570     1
# 383571     1
# Length: 383572, dtype: int64

# %% [markdown]
# ## Only 20yrs of data is present in the dataframe but among them we can see some rows have 20 missing values. So dropping rows with more than 15 missing values

# %%
df.dropna(axis=1, thresh=15, inplace=True)

# %%
df = df.transpose()
# Out:
# Country Name           0
# Country Code           0
# Indicator Name         0
# Indicator Code         0
# 2000              194518
# 2001              201406
# 2002              198175
# 2003              196070
# 2004              190788
# 2005              179048
# 2006              178897
# 2007              176683
# 2008              175906
# 2009              174744
# 2010              163405
# 2011              167956
# 2012              165985
# 2013              168872
# 2014              161663
# 2015              161892
# 2016              165942
# 2017              170148
# 2018              172567
# 2019              182156
# 2020              220700
# 2021              288710
# dtype: int64

# %%
df.drop(columns=['Unnamed: 66', '2021', 'Country Code', 'Indicator Code'], axis=1, inplace=True)

# %%
df
# Out:
#                        Country Name  \
# 0       Africa Eastern and Southern
# 1       Africa Eastern and Southern
# 2       Africa Eastern and Southern
# 3       Africa Eastern and Southern
# 4       Africa Eastern and Southern
# ...                             ...
# 383555                     Zimbabwe
# 383557                     Zimbabwe
# 383559                     Zimbabwe
# 383570                     Zimbabwe
# 383571                     Zimbabwe
#
#                                            Indicator Name       2000  \
# 0       Access to clean fuels and technologies for coo...  11.569626
# 1       Access to clean fuels and technologies for coo...   3.545501
# 2       Access to clean fuels and technologies for coo...  32.566135
# 3                 Access to electricity (% of population)   19.95793
# 4       Access to electricity, rural (% of rural popul...    8.62311
# ...                                                   ...        ...
# ...

# %% [markdown]
# m_df
